# %% [markdown]
# <a href="https://colab.research.google.com/github/Jack-Morgan22/BigData/blob/main/BigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data Analysis Libraries
import numpy as np
import pandas as pd

#Visualisation Libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

#Google Colab Import Files
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5bb96e45-82ae-454f-871d-dd12a70e135d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bb96e45-82ae-454f-871d-dd12a70e135d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
GradData = pd.read_csv(io.BytesIO(uploaded['table-1-2020-21 (2).csv']))
AreaQuali = pd.read_csv(io.BytesIO(uploaded['nomis_2024_03_04_132215 (1).csv']))
SERank = pd.read_csv(io.BytesIO(uploaded['NS-SEC_2021 (1).csv']))

# %%
#Testing CSV Files Have Correctly Imported
print(GradData.columns)
print(AreaQuali.columns)
print(SERank.columns)
# Out:
# Index(['UKPRN', 'Provider name', 'Country of provider', 'Domicile',
#        'Level of qualification obtained', 'Mode of former study',
#        'Interim study', 'Sex', 'Activity', 'Academic year', 'Number'],
#       dtype='object')
# Index(['2022 local authorities: county', 'No qualifications',
#        'Level 1 and entry level qualifications', 'Level 2 qualifications',
#        'Apprenticeship', 'Level 3 qualifications',
#        'Level 4 qualifications or above', 'Other qualifications'],
#       dtype='object')
# Index(['ONSConstID', 'ConstituencyName', 'RegNationID', 'RegNationName',
#        'NatComparator', 'variables', 'groups', 'Con_num', 'Con_pc', 'RN_pc',
#        'Nat_pc', 'ranking_total', 'rank'],
#       dtype='object')

# %%
#See A Summary Of All The Datasets
GradData.describe(include = "all")
# Out:
#                UKPRN        Provider name Country of provider Domicile  \
# count   1.048561e+06              1048561             1048561  1048561
# unique           NaN                  340                   5        4
# top              NaN  The Open University                 All      All
# freq             NaN                 6656              522880   409663
# mean    1.000964e+07                  NaN                 NaN      NaN
# std     1.331511e+04                  NaN                 NaN      NaN
# min     1.000006e+07                  NaN                 NaN      NaN
# 25%     1.000386e+07                  NaN                 NaN      NaN
# 50%     1.000714e+07                  NaN                 NaN      NaN
# 75%     1.000782e+07                  NaN                 NaN      NaN
# max     1.008659e+07                  NaN                 NaN      NaN
#
#        Level of qualification obtained Mode of former study  \
# ...

# %%
#See A Summary Of All The Datasets
AreaQuali.describe(include = "all")
# Out:
#        2022 local authorities: county No qualifications  \
# count                             174               174
# unique                            174               173
# top                        Darlington            11,418
# freq                                1                 2
#
#        Level 1 and entry level qualifications Level 2 qualifications  \
# count                                     174                    174
# unique                                    173                    174
# top                                    11,604                  6,925
# freq                                        2                      1
#
#        Apprenticeship Level 3 qualifications Level 4 qualifications or above  \
# count             174                    174                             174
# unique            173                    174                             174
# top             4,086                 11,297                          17,750
# ...

# %%
#See A Summary Of All The Datasets
SERank.describe(include = "all")
# Out:
#        ONSConstID ConstituencyName RegNationID RegNationName    NatComparator  \
# count        5157             5157        5157          5157             5157
# unique        573              573          10            10                1
# top     E14000530        Aldershot   E12000008    South East  England & Wales
# freq            9                9         756           756             5157
# mean          NaN              NaN         NaN           NaN              NaN
# std           NaN              NaN         NaN           NaN              NaN
# min           NaN              NaN         NaN           NaN              NaN
# 25%           NaN              NaN         NaN           NaN              NaN
# 50%           NaN              NaN         NaN           NaN              NaN
# 75%           NaN              NaN         NaN           NaN              NaN
# max           NaN              NaN         NaN           NaN              NaN
#
# ...
